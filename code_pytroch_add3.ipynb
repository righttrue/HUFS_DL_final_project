# %%
import sys
import os

import time
import glob 
import random
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from PIL import Image

import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader

from torchvision import transforms
from torchvision.io import read_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, folder_path, transform=None, target_transform=None):

        self.img_labels = []
        self.img_paths = []
        self.transform = transform
        self.target_transform = target_transform

        # Map class names to numerical labels
        self.classes = [
            'Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed',
            'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize',
            'Scentless Mayweed', 'Shepherds Purse', 
            'Small-flowered Cranesbill', 'Sugar beet'
        ]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}

        # Traverse folder structure
        for class_name in os.listdir(folder_path):
            class_path = os.path.join(folder_path, class_name)
            if os.path.isdir(class_path):
                label = self.class_to_idx[class_name]
                for img_file in os.listdir(class_path):
                    img_path = os.path.join(class_path, img_file)
                    if img_path.endswith(('.png', '.jpg', '.jpeg')):  # Filter valid image files
                        self.img_paths.append(img_path)
                        self.img_labels.append(label)

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        image = Image.open(img_path).convert("RGB")  # Convert to RGB
        label = self.img_labels[idx]
        
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        
        return image, label
    

class MinMaxScaler:
    def __init__(self, min_value=0.0, max_value=1.0):
        self.min_value = min_value
        self.max_value = max_value

    def __call__(self, tensor):
        min_val = tensor.min()
        max_val = tensor.max()
        return (tensor - min_val) / (max_val - min_val + 1e-7) * (self.max_value - self.min_value) + self.min_value
    

transform = transforms.Compose([
    transforms.Resize((64, 64)),  
    transforms.ToTensor(),
    MinMaxScaler(min_value=0.0, max_value=1.0) 
])

# %%
train_folder = './Data/train'
val_folder = './Data/validation'
test_folder = './Data/test'

train_dataset = CustomImageDataset(train_folder, transform=transform)
test_dataset = CustomImageDataset(test_folder, transform=transform)
val_dataset = CustomImageDataset(val_folder, transform=transform)

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=True)    
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
learning_rate = 0.00001
batch_size = 64
epochs = 100

class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        # self.flatten = nn.Flatten()
        self.layer  = nn.Sequential(
            # kernel1
            nn.Conv2d(in_channels=3,out_channels=64,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),
            # pool
            nn.MaxPool2d(kernel_size=2,stride=2),        
            
            # kernel2
            nn.Conv2d(in_channels=64,out_channels=128,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),        

            # kernel3_1
            nn.Conv2d(in_channels=128,out_channels=256,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),

            # kernel3_2
            nn.Conv2d(in_channels=256,out_channels=256,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),
            
            # kernel3_3
            nn.Conv2d(in_channels=256,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),    

            # kernel3_4 #add3_ver
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),  
            nn.MaxPool2d(kernel_size=2,stride=2),

            # kernel4_1
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),

            # kernel4_2
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),

            # kernel4_3 #add3_ver
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),

            # kernel5_1
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),    

            # kernel5_2
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),    


            # kernel5_3 #add3_ver
            nn.Conv2d(in_channels=512,out_channels=512,kernel_size=3,stride= 1,padding = 'same', bias = True),
            nn.ReLU(),    
            nn.MaxPool2d(kernel_size=2,stride=2),
    )

        self.fc_layer = nn.Sequential(
            nn.Linear(2 * 2 * 512, 1024),  
            nn.ReLU(),
            nn.Linear(1024, 12),
        )

    def forward(self,x):
    	# self.layer에 정의한 연산 수행
        out = self.layer(x)
        out = out.view(out.size(0), -1)
        # self.fc_layer 정의한 연산 수행    
        out = self.fc_layer(out)
        return out

# %%
# Define the model
model = NeuralNetwork().to(device)
print(model)

# 손실 함수를 초기화
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# NeuralNetwork(
#   (layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (9): ReLU()
#     (10): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (16): ReLU()
#     (17): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (18): ReLU()
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (20): ReLU()
#     (21): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (23): ReLU()
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (25): ReLU()
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (27): ReLU()
#     (28): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layer): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=12, bias=True)
#   )
# )

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)

    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # 예측(prediction)과 손실(loss) 계산
        pred = model(X)
        test_loss, correct = 0, 0

        # 역전파
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        correct /= size
        if batch % 64 == 0:
            loss = loss.item()
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            loss = loss_fn(pred, y)
            print(f"train loss: {loss:.03f} train accuracy {correct:>5d}/{size:>5d}]")

    return loss


def test_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    
    with torch.no_grad():
        for batch, (X, y) in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):0.2f}, Avg loss: {test_loss:>8f} \n")

def val_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):0.2f}, Avg loss: {test_loss:>8f} \n")

# %%
# Hyperparameters
learning_rate = 0.00001
batch_size = 64
n_epochs = 100

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training and validation loop
loss_train_history = []
acc_train_history = []
loss_val_history = []
acc_val_history = []

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(n_epochs):
    # Training phase
    model.train()
    total_train_loss = 0
    total_train_correct = 0
    for X_train_batch, Y_train_batch in train_dataloader:
        X_train_batch, Y_train_batch = X_train_batch.to(device), Y_train_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_train_batch)
        loss = criterion(outputs, Y_train_batch)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train_correct += (predicted == Y_train_batch).sum().item()

    train_loss = total_train_loss / len(train_dataloader)
    train_accuracy = total_train_correct / len(train_dataset)
    loss_train_history.append(train_loss)
    acc_train_history.append(train_accuracy)

    # Validation phase
    model.eval()
    total_val_loss = 0
    total_val_correct = 0
    with torch.no_grad():
        for X_val_batch, Y_val_batch in val_dataloader:
            X_val_batch, Y_val_batch = X_val_batch.to(device), Y_val_batch.to(device)

            outputs = model(X_val_batch)
            loss = criterion(outputs, Y_val_batch)
            total_val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_val_correct += (predicted == Y_val_batch).sum().item()

    val_loss = total_val_loss / len(val_dataloader)
    val_accuracy = total_val_correct / len(val_dataset)
    loss_val_history.append(val_loss)
    acc_val_history.append(val_accuracy)

    print(f"Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.3f}, Train Accuracy: {train_accuracy:.3f}, "
          f"Val Loss: {val_loss:.3f}, Val Accuracy: {val_accuracy:.3f}")

# Testing phase
model.eval()
total_test_correct = 0
with torch.no_grad():
    for X_test_batch, Y_test_batch in test_dataloader:
        X_test_batch, Y_test_batch = X_test_batch.to(device), Y_test_batch.to(device)

        outputs = model(X_test_batch)
        _, predicted = torch.max(outputs, 1)
        total_test_correct += (predicted == Y_test_batch).sum().item()

test_accuracy = total_test_correct / len(test_dataset)
print(f"Test Accuracy: {test_accuracy:.3f}")
# Out:
# Epoch 1/100, Train Loss: 2.474, Train Accuracy: 0.103, Val Loss: 2.489, Val Accuracy: 0.116
# Epoch 2/100, Train Loss: 2.409, Train Accuracy: 0.134, Val Loss: 2.460, Val Accuracy: 0.094
# Epoch 3/100, Train Loss: 2.408, Train Accuracy: 0.143, Val Loss: 2.460, Val Accuracy: 0.116
# Epoch 4/100, Train Loss: 2.404, Train Accuracy: 0.135, Val Loss: 2.449, Val Accuracy: 0.094
# Epoch 5/100, Train Loss: 2.404, Train Accuracy: 0.123, Val Loss: 2.447, Val Accuracy: 0.094
# Epoch 6/100, Train Loss: 2.402, Train Accuracy: 0.135, Val Loss: 2.432, Val Accuracy: 0.121
# Epoch 7/100, Train Loss: 2.390, Train Accuracy: 0.128, Val Loss: 2.416, Val Accuracy: 0.116
# Epoch 8/100, Train Loss: 2.396, Train Accuracy: 0.130, Val Loss: 2.413, Val Accuracy: 0.116
# Epoch 9/100, Train Loss: 2.384, Train Accuracy: 0.135, Val Loss: 2.420, Val Accuracy: 0.121
# Epoch 10/100, Train Loss: 2.382, Train Accuracy: 0.146, Val Loss: 2.401, Val Accuracy: 0.125
# Epoch 11/100, Train Loss: 2.376, Train Accuracy: 0.155, Val Loss: 2.389, Val Accuracy: 0.132
# Epoch 12/100, Train Loss: 2.355, Train Accuracy: 0.161, Val Loss: 2.360, Val Accuracy: 0.123
# Epoch 13/100, Train Loss: 2.336, Train Accuracy: 0.163, Val Loss: 2.366, Val Accuracy: 0.130
# Epoch 14/100, Train Loss: 2.314, Train Accuracy: 0.168, Val Loss: 2.354, Val Accuracy: 0.150
# Epoch 15/100, Train Loss: 2.272, Train Accuracy: 0.182, Val Loss: 2.287, Val Accuracy: 0.215
# Epoch 16/100, Train Loss: 2.180, Train Accuracy: 0.249, Val Loss: 2.135, Val Accuracy: 0.233
# Epoch 17/100, Train Loss: 1.970, Train Accuracy: 0.310, Val Loss: 1.936, Val Accuracy: 0.324
# Epoch 18/100, Train Loss: 1.795, Train Accuracy: 0.385, Val Loss: 1.699, Val Accuracy: 0.416
# Epoch 19/100, Train Loss: 1.670, Train Accuracy: 0.421, Val Loss: 1.691, Val Accuracy: 0.421
# Epoch 20/100, Train Loss: 1.607, Train Accuracy: 0.443, Val Loss: 1.635, Val Accuracy: 0.434
# Epoch 21/100, Train Loss: 1.537, Train Accuracy: 0.461, Val Loss: 1.581, Val Accuracy: 0.427
# Epoch 22/100, Train Loss: 1.497, Train Accuracy: 0.478, Val Loss: 1.545, Val Accuracy: 0.474
# Epoch 23/100, Train Loss: 1.468, Train Accuracy: 0.479, Val Loss: 1.699, Val Accuracy: 0.403
# Epoch 24/100, Train Loss: 1.459, Train Accuracy: 0.479, Val Loss: 1.687, Val Accuracy: 0.371
# Epoch 25/100, Train Loss: 1.427, Train Accuracy: 0.493, Val Loss: 1.459, Val Accuracy: 0.465
# Epoch 26/100, Train Loss: 1.388, Train Accuracy: 0.504, Val Loss: 1.546, Val Accuracy: 0.432
# Epoch 27/100, Train Loss: 1.370, Train Accuracy: 0.512, Val Loss: 1.395, Val Accuracy: 0.492
# Epoch 28/100, Train Loss: 1.378, Train Accuracy: 0.520, Val Loss: 1.435, Val Accuracy: 0.494
# Epoch 29/100, Train Loss: 1.343, Train Accuracy: 0.524, Val Loss: 1.385, Val Accuracy: 0.506
# Epoch 30/100, Train Loss: 1.360, Train Accuracy: 0.523, Val Loss: 1.385, Val Accuracy: 0.510
# Epoch 31/100, Train Loss: 1.318, Train Accuracy: 0.545, Val Loss: 1.363, Val Accuracy: 0.506
# Epoch 32/100, Train Loss: 1.279, Train Accuracy: 0.551, Val Loss: 1.413, Val Accuracy: 0.488
# Epoch 33/100, Train Loss: 1.262, Train Accuracy: 0.549, Val Loss: 1.504, Val Accuracy: 0.470
# Epoch 34/100, Train Loss: 1.283, Train Accuracy: 0.557, Val Loss: 1.356, Val Accuracy: 0.517
# Epoch 35/100, Train Loss: 1.261, Train Accuracy: 0.555, Val Loss: 1.316, Val Accuracy: 0.535
# Epoch 36/100, Train Loss: 1.245, Train Accuracy: 0.557, Val Loss: 1.336, Val Accuracy: 0.532
# Epoch 37/100, Train Loss: 1.233, Train Accuracy: 0.568, Val Loss: 1.306, Val Accuracy: 0.508
# Epoch 38/100, Train Loss: 1.191, Train Accuracy: 0.584, Val Loss: 1.320, Val Accuracy: 0.526
# Epoch 39/100, Train Loss: 1.192, Train Accuracy: 0.576, Val Loss: 1.346, Val Accuracy: 0.501
# Epoch 40/100, Train Loss: 1.167, Train Accuracy: 0.593, Val Loss: 1.270, Val Accuracy: 0.548
# Epoch 41/100, Train Loss: 1.147, Train Accuracy: 0.600, Val Loss: 1.313, Val Accuracy: 0.526
# Epoch 42/100, Train Loss: 1.178, Train Accuracy: 0.586, Val Loss: 1.359, Val Accuracy: 0.485
# Epoch 43/100, Train Loss: 1.128, Train Accuracy: 0.602, Val Loss: 1.246, Val Accuracy: 0.532
# Epoch 44/100, Train Loss: 1.103, Train Accuracy: 0.601, Val Loss: 1.247, Val Accuracy: 0.555
# Epoch 45/100, Train Loss: 1.080, Train Accuracy: 0.611, Val Loss: 1.242, Val Accuracy: 0.557
# Epoch 46/100, Train Loss: 1.105, Train Accuracy: 0.616, Val Loss: 1.268, Val Accuracy: 0.528
# Epoch 47/100, Train Loss: 1.084, Train Accuracy: 0.625, Val Loss: 1.349, Val Accuracy: 0.503
# Epoch 48/100, Train Loss: 1.052, Train Accuracy: 0.623, Val Loss: 1.207, Val Accuracy: 0.562
# Epoch 49/100, Train Loss: 1.030, Train Accuracy: 0.631, Val Loss: 1.244, Val Accuracy: 0.557
# Epoch 50/100, Train Loss: 1.034, Train Accuracy: 0.633, Val Loss: 1.173, Val Accuracy: 0.577
# Epoch 51/100, Train Loss: 1.010, Train Accuracy: 0.641, Val Loss: 1.239, Val Accuracy: 0.566
# Epoch 52/100, Train Loss: 0.995, Train Accuracy: 0.643, Val Loss: 1.167, Val Accuracy: 0.602
# Epoch 53/100, Train Loss: 1.002, Train Accuracy: 0.647, Val Loss: 1.184, Val Accuracy: 0.566
# Epoch 54/100, Train Loss: 0.970, Train Accuracy: 0.659, Val Loss: 1.181, Val Accuracy: 0.573
# Epoch 55/100, Train Loss: 0.953, Train Accuracy: 0.662, Val Loss: 1.327, Val Accuracy: 0.532
# Epoch 56/100, Train Loss: 1.010, Train Accuracy: 0.645, Val Loss: 1.203, Val Accuracy: 0.575
# Epoch 57/100, Train Loss: 0.970, Train Accuracy: 0.655, Val Loss: 1.135, Val Accuracy: 0.600
# Epoch 58/100, Train Loss: 0.940, Train Accuracy: 0.664, Val Loss: 1.162, Val Accuracy: 0.593
# Epoch 59/100, Train Loss: 0.942, Train Accuracy: 0.675, Val Loss: 1.136, Val Accuracy: 0.606
# Epoch 60/100, Train Loss: 0.892, Train Accuracy: 0.677, Val Loss: 1.148, Val Accuracy: 0.602
# Epoch 61/100, Train Loss: 0.884, Train Accuracy: 0.692, Val Loss: 1.132, Val Accuracy: 0.597
# Epoch 62/100, Train Loss: 0.874, Train Accuracy: 0.688, Val Loss: 1.091, Val Accuracy: 0.613
# Epoch 63/100, Train Loss: 0.859, Train Accuracy: 0.692, Val Loss: 1.137, Val Accuracy: 0.602
# Epoch 64/100, Train Loss: 0.832, Train Accuracy: 0.699, Val Loss: 1.102, Val Accuracy: 0.609
# Epoch 65/100, Train Loss: 0.815, Train Accuracy: 0.712, Val Loss: 1.157, Val Accuracy: 0.609
# Epoch 66/100, Train Loss: 0.797, Train Accuracy: 0.722, Val Loss: 1.075, Val Accuracy: 0.631
# Epoch 67/100, Train Loss: 0.799, Train Accuracy: 0.727, Val Loss: 1.512, Val Accuracy: 0.515
# Epoch 68/100, Train Loss: 0.857, Train Accuracy: 0.697, Val Loss: 1.122, Val Accuracy: 0.611
# Epoch 69/100, Train Loss: 0.758, Train Accuracy: 0.741, Val Loss: 1.130, Val Accuracy: 0.615
# Epoch 70/100, Train Loss: 0.723, Train Accuracy: 0.744, Val Loss: 1.186, Val Accuracy: 0.588
# Epoch 71/100, Train Loss: 0.706, Train Accuracy: 0.750, Val Loss: 1.056, Val Accuracy: 0.633
# Epoch 72/100, Train Loss: 0.705, Train Accuracy: 0.751, Val Loss: 1.145, Val Accuracy: 0.615
# Epoch 73/100, Train Loss: 0.694, Train Accuracy: 0.755, Val Loss: 1.061, Val Accuracy: 0.653
# Epoch 74/100, Train Loss: 0.674, Train Accuracy: 0.762, Val Loss: 1.128, Val Accuracy: 0.604
# Epoch 75/100, Train Loss: 0.684, Train Accuracy: 0.759, Val Loss: 1.197, Val Accuracy: 0.600
# Epoch 76/100, Train Loss: 0.724, Train Accuracy: 0.743, Val Loss: 1.084, Val Accuracy: 0.655
# Epoch 77/100, Train Loss: 0.626, Train Accuracy: 0.777, Val Loss: 1.114, Val Accuracy: 0.617
# Epoch 78/100, Train Loss: 0.628, Train Accuracy: 0.772, Val Loss: 1.052, Val Accuracy: 0.655
# Epoch 79/100, Train Loss: 0.653, Train Accuracy: 0.770, Val Loss: 1.039, Val Accuracy: 0.664
# Epoch 80/100, Train Loss: 0.604, Train Accuracy: 0.788, Val Loss: 1.102, Val Accuracy: 0.640
# Epoch 81/100, Train Loss: 0.632, Train Accuracy: 0.784, Val Loss: 1.035, Val Accuracy: 0.638
# Epoch 82/100, Train Loss: 0.578, Train Accuracy: 0.790, Val Loss: 1.041, Val Accuracy: 0.640
# Epoch 83/100, Train Loss: 0.546, Train Accuracy: 0.810, Val Loss: 1.075, Val Accuracy: 0.667
# Epoch 84/100, Train Loss: 0.558, Train Accuracy: 0.798, Val Loss: 1.029, Val Accuracy: 0.649
# Epoch 85/100, Train Loss: 0.539, Train Accuracy: 0.808, Val Loss: 1.090, Val Accuracy: 0.649
# Epoch 86/100, Train Loss: 0.534, Train Accuracy: 0.810, Val Loss: 1.262, Val Accuracy: 0.611
# Epoch 87/100, Train Loss: 0.568, Train Accuracy: 0.798, Val Loss: 1.110, Val Accuracy: 0.642
# Epoch 88/100, Train Loss: 0.504, Train Accuracy: 0.822, Val Loss: 1.156, Val Accuracy: 0.655
# Epoch 89/100, Train Loss: 0.491, Train Accuracy: 0.821, Val Loss: 1.082, Val Accuracy: 0.678
# Epoch 90/100, Train Loss: 0.478, Train Accuracy: 0.832, Val Loss: 1.166, Val Accuracy: 0.633
# Epoch 91/100, Train Loss: 0.517, Train Accuracy: 0.811, Val Loss: 1.152, Val Accuracy: 0.651
# Epoch 92/100, Train Loss: 0.481, Train Accuracy: 0.830, Val Loss: 1.075, Val Accuracy: 0.653
# Epoch 93/100, Train Loss: 0.479, Train Accuracy: 0.833, Val Loss: 1.258, Val Accuracy: 0.642
# Epoch 94/100, Train Loss: 0.466, Train Accuracy: 0.837, Val Loss: 1.467, Val Accuracy: 0.609
# Epoch 95/100, Train Loss: 0.516, Train Accuracy: 0.814, Val Loss: 1.100, Val Accuracy: 0.660
# Epoch 96/100, Train Loss: 0.419, Train Accuracy: 0.857, Val Loss: 1.698, Val Accuracy: 0.555
# Epoch 97/100, Train Loss: 0.464, Train Accuracy: 0.838, Val Loss: 1.143, Val Accuracy: 0.664
# Epoch 98/100, Train Loss: 0.459, Train Accuracy: 0.833, Val Loss: 1.159, Val Accuracy: 0.649
# Epoch 99/100, Train Loss: 0.395, Train Accuracy: 0.857, Val Loss: 1.178, Val Accuracy: 0.664
# Epoch 100/100, Train Loss: 0.389, Train Accuracy: 0.858, Val Loss: 1.212, Val Accuracy: 0.655
# Test Accuracy: 0.684

# %%
plt.subplot(2,1,1)
plt.plot(loss_train_history, 'b-', label='Train loss value')
plt.plot(loss_val_history, 'r-', label='Val. loss value')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(ncol=2, loc='upper right')

plt.subplot(2,1,2)
plt.plot(acc_train_history, 'b-', label='Train accuracy value')
plt.plot(acc_val_history, 'r-', label='Val. accuracy value')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 10)
plt.show()
